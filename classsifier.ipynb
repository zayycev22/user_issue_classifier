# %%
from catboost import CatBoostClassifier
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("DATA/new_train.csv")
df
# Out:
#                                               Содержание    Сервис  Приоритет  \
# 0               Выполнена разблокировка у/з REGION\*****   Сервис7          2
# 1                                      .Не включается ПК       АРМ          3
# 2              Заявка № ***********, *******************       АРМ          3
# 3              Заявка № ***********, *******************       АРМ          3
# 4              Заявка № ***********, *******************       АРМ          3
# ...                                                  ...       ...        ...
# 10278  Заявка на предоставление и отзыв прав доступа ...  Сервис11          3
# 10279  Устранение уязвимостей ИБ в соответствии с Пла...       АРМ          3
# 10280            Контроль ПУ. Заявка на доступ к портам.   Сервис2          3
# 10281                                    Ремонт стульев.  Сервис73          3
# 10282  Заявка на предоставление и отзыв прав доступа ...  Сервис22          3
#
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(df[['Приоритет', 'Статус', 'Тип обращения на момент подачи', 'Критичность', 'Влияние']], df['Тип обращения итоговый'], test_size = 0.32, random_state = 370)

# %%
features = ['Приоритет', 'Статус', 'Тип обращения на момент подачи', 'Критичность', 'Влияние']
model = CatBoostClassifier(iterations=600, eval_metric='TotalF1', learning_rate=0.079, early_stopping_rounds=500, max_depth=9, )

# %%
model.fit(x_train, y_train, cat_features=features, eval_set=(x_train, y_train), use_best_model=True)
# Out:
# 0:	learn: 0.9659696	test: 0.9659696	best: 0.9659696 (0)	total: 16.2ms	remaining: 9.71s
# 1:	learn: 0.9659696	test: 0.9659696	best: 0.9659696 (0)	total: 26.1ms	remaining: 7.82s
# 2:	learn: 0.9659696	test: 0.9659696	best: 0.9659696 (0)	total: 48.9ms	remaining: 9.74s
# 3:	learn: 0.9659696	test: 0.9659696	best: 0.9659696 (0)	total: 87ms	remaining: 13s
# 4:	learn: 0.9659696	test: 0.9659696	best: 0.9659696 (0)	total: 108ms	remaining: 12.9s
# 5:	learn: 0.9659696	test: 0.9659696	best: 0.9659696 (0)	total: 121ms	remaining: 12s
# 6:	learn: 0.9659696	test: 0.9659696	best: 0.9659696 (0)	total: 134ms	remaining: 11.3s
# 7:	learn: 0.9659696	test: 0.9659696	best: 0.9659696 (0)	total: 146ms	remaining: 10.8s
# 8:	learn: 0.9659696	test: 0.9659696	best: 0.9659696 (0)	total: 156ms	remaining: 10.2s
# 9:	learn: 0.9659696	test: 0.9659696	best: 0.9659696 (0)	total: 183ms	remaining: 10.8s
# 10:	learn: 0.9659696	test: 0.9659696	best: 0.9659696 (0)	total: 215ms	remaining: 11.5s
# ...

# %%
ans = model.predict(x_test)
ans
# Out:
# array([0, 1, 0, ..., 0, 0, 0], dtype=int64)

# %%
model.get_feature_importance(prettified=True)
# Out:
#                        Feature Id  Importances
# 0                         Влияние    35.579959
# 1                     Критичность    32.231102
# 2  Тип обращения на момент подачи    17.750043
# 3                       Приоритет    11.094919
# 4                          Статус     3.343977
